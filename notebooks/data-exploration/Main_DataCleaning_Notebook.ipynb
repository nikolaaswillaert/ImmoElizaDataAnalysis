# %% [markdown]
# # 1. CLEANING THE DATA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/dataframe_20k_290623.csv').drop(columns=['Unnamed: 0'])

# %%
# Merge with dataframe that has all localities + regions
df_location = pd.read_csv('../../data/dataframe_locality.csv').drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
df_location = df_location[['locality','region','province']]
df_new = pd.merge(df, df_location, on='locality', how='left')
df_new.drop_duplicates(inplace=True)
df_new.reset_index(inplace=True, drop=True)

df = df_new

# %%
df[df['region'].isnull()]
# drop the null values
df.dropna(subset=['region'], inplace=True)

# %%
# Getting to know the dataframe
df.head()
# Out:
#      locality type of property subtype of property     price  number_rooms  \
# 0         Ham            HOUSE               VILLA  429500.0           4.0
# 1       Putte            HOUSE               HOUSE  599000.0           5.0
# 2  IVOZ-RAMET            HOUSE               HOUSE   20000.0           3.0
# 3     Herstal            HOUSE               HOUSE   45000.0           2.0
# 4       Liege            HOUSE               HOUSE  109000.0           2.0
#
#    living_area        kitchen furnished  fireplace terrace  terrace_area  \
# 0        215.0      INSTALLED       NaN       -1.0     NaN           NaN
# 1        167.0      INSTALLED       NaN       -1.0    True           NaN
# 2        130.0      INSTALLED       NaN       -1.0    True           NaN
# 3        120.0  USA_INSTALLED      True        NaN    True          12.0
# 4         62.0  SEMI_EQUIPPED     False        NaN     NaN           NaN
#
#   garden  garden_area surface_land number_facades swimming_pool  \
# 0   True          NaN         1472              4           NaN
# 1   True         95.0          416              4           NaN
# 2    NaN          NaN          182              3           NaN
# 3   True         80.0          221              2         False
# 4    NaN          NaN           45              2         False
#
#    building_state    region province
# 0            GOOD  Flanders  Limburg
# 1  JUST_RENOVATED  Flanders  Antwerp
# 2            GOOD  Wallonie    Liège
# 3   TO_BE_DONE_UP  Wallonie    Liège
# 4   TO_BE_DONE_UP  Wallonie    Liège

# %%
# Rename the columns to be consistent in naming convention
df.rename(columns = {'type of property':'property_type', 'subtype of property':'property_subtype'}, inplace = True)
df.head()
# Out:
#      locality property_type property_subtype     price  number_rooms  \
# 0         Ham         HOUSE            VILLA  429500.0           4.0
# 1       Putte         HOUSE            HOUSE  599000.0           5.0
# 2  IVOZ-RAMET         HOUSE            HOUSE   20000.0           3.0
# 3     Herstal         HOUSE            HOUSE   45000.0           2.0
# 4       Liege         HOUSE            HOUSE  109000.0           2.0
#
#    living_area        kitchen furnished  fireplace terrace  terrace_area  \
# 0        215.0      INSTALLED       NaN       -1.0     NaN           NaN
# 1        167.0      INSTALLED       NaN       -1.0    True           NaN
# 2        130.0      INSTALLED       NaN       -1.0    True           NaN
# 3        120.0  USA_INSTALLED      True        NaN    True          12.0
# 4         62.0  SEMI_EQUIPPED     False        NaN     NaN           NaN
#
#   garden  garden_area surface_land number_facades swimming_pool  \
# 0   True          NaN         1472              4           NaN
# 1   True         95.0          416              4           NaN
# 2    NaN          NaN          182              3           NaN
# 3   True         80.0          221              2         False
# 4    NaN          NaN           45              2         False
#
#    building_state    region province
# 0            GOOD  Flanders  Limburg
# 1  JUST_RENOVATED  Flanders  Antwerp
# 2            GOOD  Wallonie    Liège
# 3   TO_BE_DONE_UP  Wallonie    Liège
# 4   TO_BE_DONE_UP  Wallonie    Liège

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17064 entries, 0 to 17676
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   locality          17064 non-null  object
#  1   property_type     17064 non-null  object
#  2   property_subtype  17064 non-null  object
#  3   price             16754 non-null  float64
#  4   number_rooms      16754 non-null  float64
#  5   living_area       15798 non-null  float64
#  6   kitchen           15483 non-null  object
#  7   furnished         8310 non-null   object
#  8   fireplace         5309 non-null   float64
#  9   terrace           11075 non-null  object
#  10  terrace_area      6461 non-null   float64
#  11  garden            7688 non-null   object
#  12  garden_area       5008 non-null   float64
#  13  surface_land      15358 non-null  object
#  14  number_facades    14051 non-null  object
#  15  swimming_pool     8770 non-null   object
#  16  building_state    14135 non-null  object
#  17  region            17064 non-null  object
#  18  province          17064 non-null  object
# dtypes: float64(6), object(13)
# memory usage: 2.6+ MB

# %%
df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17064 entries, 0 to 17676
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   locality          17064 non-null  object
#  1   property_type     17064 non-null  object
#  2   property_subtype  17064 non-null  object
#  3   price             16754 non-null  float64
#  4   number_rooms      16754 non-null  float64
#  5   living_area       15798 non-null  float64
#  6   kitchen           15483 non-null  object
#  7   furnished         8310 non-null   object
#  8   fireplace         5309 non-null   float64
#  9   terrace           11075 non-null  object
#  10  terrace_area      6461 non-null   float64
#  11  garden            7688 non-null   object
#  12  garden_area       5008 non-null   float64
#  13  surface_land      15358 non-null  object
#  14  number_facades    14051 non-null  object
#  15  swimming_pool     8770 non-null   object
#  16  building_state    14135 non-null  object
#  17  region            17064 non-null  object
#  18  province          17064 non-null  object
# dtypes: float64(6), object(13)
# memory usage: 2.6+ MB

# %%
# Write a function to show all the interesting values of a column
def analyze_column(df, column_name):
    column = df[column_name]
    num_nan = column.isnull().sum()
    num_unique = column.nunique()
    unique_values = column.unique()
    percentage_nan = (num_nan / len(column)) * 100
    percentage_unique = (num_unique / len(column)) * 100
    print(f"Analysis for column '{column_name}':")
    print(f"Number of NaN values: {num_nan}")
    print(f"Number of unique values: {num_unique}")
    print(f"Percentage of NaN values: {percentage_nan:.2f}%")
    print(f"Percentage of unique values: {percentage_unique:.2f}%")
    print(f"Unique values: {unique_values}")

# %%
# write function to create a graph for categorical values
def create_cat_plot(df,column, angle):
    sns.catplot(x=column, y="price", data=df)
    # Set labels and title
    plt.xlabel(f"{column}")
    plt.ylabel("Price (in euro)")
    plt.title(f"{column} vs. Price")
    plt.xticks(rotation=angle)
    # Show the plot
    plt.show()

# %%
# write function to create a graph for numerical values
def create_num_plot(df, column):
    sns.scatterplot(x=column, y='price', data=df)
    plt.xlabel(f"{column}")
    plt.ylabel("Price (in euro)")
    plt.title(f"{column} vs. Price")
    # Show the plot
    plt.show()

# %%
# Write function to remove outlyers
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
    return data

# %%
# Remove the rows that have all NaN values
df = df.dropna(how='all')

# %%
df.head()
# Out:
#      locality property_type property_subtype     price  number_rooms  \
# 0         Ham         HOUSE            VILLA  429500.0           4.0
# 1       Putte         HOUSE            HOUSE  599000.0           5.0
# 2  IVOZ-RAMET         HOUSE            HOUSE   20000.0           3.0
# 3     Herstal         HOUSE            HOUSE   45000.0           2.0
# 4       Liege         HOUSE            HOUSE  109000.0           2.0
#
#    living_area        kitchen furnished  fireplace terrace  terrace_area  \
# 0        215.0      INSTALLED       NaN       -1.0     NaN           NaN
# 1        167.0      INSTALLED       NaN       -1.0    True           NaN
# 2        130.0      INSTALLED       NaN       -1.0    True           NaN
# 3        120.0  USA_INSTALLED      True        NaN    True          12.0
# 4         62.0  SEMI_EQUIPPED     False        NaN     NaN           NaN
#
#   garden  garden_area surface_land number_facades swimming_pool  \
# 0   True          NaN         1472              4           NaN
# 1   True         95.0          416              4           NaN
# 2    NaN          NaN          182              3           NaN
# 3   True         80.0          221              2         False
# 4    NaN          NaN           45              2         False
#
#    building_state    region province
# 0            GOOD  Flanders  Limburg
# 1  JUST_RENOVATED  Flanders  Antwerp
# 2            GOOD  Wallonie    Liège
# 3   TO_BE_DONE_UP  Wallonie    Liège
# 4   TO_BE_DONE_UP  Wallonie    Liège

# %% [markdown]
# ### 0. Price

# %%
# If we dont have a price - Delete the rows - not useable to predict pricing!
# This will be what we will need to predict
df['price'].info()
df.price.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 17064 entries, 0 to 17676
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 16754 non-null  float64
# dtypes: float64(1)
# memory usage: 266.6 KB
# <class 'pandas.core.series.Series'>
# Index: 17064 entries, 0 to 17676
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 16754 non-null  float64
# dtypes: float64(1)
# memory usage: 266.6 KB

# %%
# We have 475 rows with NaN as price - 2.38% of the total
analyze_column(df, 'price')
# Out:
# Analysis for column 'price':
# Number of NaN values: 310
# Number of unique values: 1590
# Percentage of NaN values: 1.82%
# Percentage of unique values: 9.32%
# Unique values: [429500. 599000.  20000. ... 381500. 351000. 176000.]

# %%
df[df['price'].isna()]
# Most values are not Filled in (NaN) so I decide to drop all of these 475 rows
# Out:
#         locality    property_type property_subtype  price  number_rooms  \
# 48     Roeselare  APARTMENT_GROUP  APARTMENT_GROUP    NaN           NaN
# 93         Evere  APARTMENT_GROUP  APARTMENT_GROUP    NaN           NaN
# 184        Balen      HOUSE_GROUP      HOUSE_GROUP    NaN           NaN
# 185      HERSELT      HOUSE_GROUP      HOUSE_GROUP    NaN           NaN
# 186      WITGOOR      HOUSE_GROUP      HOUSE_GROUP    NaN           NaN
# ...          ...              ...              ...    ...           ...
# 16596    Berlare      HOUSE_GROUP      HOUSE_GROUP    NaN           NaN
# 16977   Borgloon      HOUSE_GROUP      HOUSE_GROUP    NaN           NaN
# 17300   Borgloon  APARTMENT_GROUP  APARTMENT_GROUP    NaN           NaN
# 17456     Dessel      HOUSE_GROUP      HOUSE_GROUP    NaN           NaN
# 17464    Waregem  APARTMENT_GROUP  APARTMENT_GROUP    NaN           NaN
#
#        living_area kitchen furnished  fireplace terrace  terrace_area garden  \
# 48             NaN       0     False        NaN     NaN           NaN    NaN
# 93             NaN       0       NaN        NaN     NaN           NaN    NaN
# 184            NaN       0     False        NaN     NaN           NaN    NaN
# 185            NaN       0       NaN        NaN     NaN           NaN    NaN
# 186            NaN       0       NaN        NaN     NaN           NaN    NaN
# ...            ...     ...       ...        ...     ...           ...    ...
# 16596          NaN       0       NaN        NaN     NaN           NaN    NaN
# 16977          NaN       0       NaN        NaN     NaN           NaN    NaN
# 17300          NaN       0       NaN        NaN     NaN           NaN    NaN
# 17456          NaN       0       NaN        NaN     NaN           NaN    NaN
# 17464          NaN       0       NaN        NaN     NaN           NaN    NaN
#
#        garden_area surface_land number_facades swimming_pool building_state  \
# 48             NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
# 93             NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
# 184            NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
# 185            NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
# 186            NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
# ...            ...          ...            ...           ...            ...
# 16596          NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
# 16977          NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
# 17300          NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
# 17456          NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
# 17464          NaN      UNKNOWN        UNKNOWN           NaN        UNKNOWN
#
#          region       province
# 48     Flanders  West Flanders
# 93     Brussels       Brussels
# 184    Flanders        Antwerp
# 185    Flanders        Antwerp
# 186    Flanders        Antwerp
# ...         ...            ...
# 16596  Flanders  East Flanders
# 16977  Flanders        Limburg
# 17300  Flanders        Limburg
# 17456  Flanders        Antwerp
# 17464  Flanders  West Flanders
#
# [310 rows x 19 columns]

# %%
df = df.dropna(subset=['price'])

# %%
df[df['price'].isna()]
# ALL NaN Values are dropped
# Out:
# Empty DataFrame
# Columns: [locality, property_type, property_subtype, price, number_rooms, living_area, kitchen, furnished, fireplace, terrace, terrace_area, garden, garden_area, surface_land, number_facades, swimming_pool, building_state, region, province]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16754 entries, 0 to 17676
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   locality          16754 non-null  object
#  1   property_type     16754 non-null  object
#  2   property_subtype  16754 non-null  object
#  3   price             16754 non-null  float64
#  4   number_rooms      16754 non-null  float64
#  5   living_area       15798 non-null  float64
#  6   kitchen           15173 non-null  object
#  7   furnished         8264 non-null   object
#  8   fireplace         5309 non-null   float64
#  9   terrace           11075 non-null  object
#  10  terrace_area      6461 non-null   float64
#  11  garden            7688 non-null   object
#  12  garden_area       5008 non-null   float64
#  13  surface_land      15048 non-null  object
#  14  number_facades    13741 non-null  object
#  15  swimming_pool     8770 non-null   object
#  16  building_state    13825 non-null  object
#  17  region            16754 non-null  object
#  18  province          16754 non-null  object
# dtypes: float64(6), object(13)
# memory usage: 2.6+ MB

# %%
# Resetting index to have nice looking dataframe
df.reset_index(inplace=True, drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16754 entries, 0 to 16753
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   locality          16754 non-null  object
#  1   property_type     16754 non-null  object
#  2   property_subtype  16754 non-null  object
#  3   price             16754 non-null  float64
#  4   number_rooms      16754 non-null  float64
#  5   living_area       15798 non-null  float64
#  6   kitchen           15173 non-null  object
#  7   furnished         8264 non-null   object
#  8   fireplace         5309 non-null   float64
#  9   terrace           11075 non-null  object
#  10  terrace_area      6461 non-null   float64
#  11  garden            7688 non-null   object
#  12  garden_area       5008 non-null   float64
#  13  surface_land      15048 non-null  object
#  14  number_facades    13741 non-null  object
#  15  swimming_pool     8770 non-null   object
#  16  building_state    13825 non-null  object
#  17  region            16754 non-null  object
#  18  province          16754 non-null  object
# dtypes: float64(6), object(13)
# memory usage: 2.4+ MB

# %%
# convert to integers
df['price'] = pd.to_numeric(df['price'])
df_price_outlyers = df[df['price'] <= 1350000]
sns.histplot(df_price_outlyers, x='price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# need to filter out the outlyers
df = remove_outliers_iqr(df, 'price')
sns.histplot(x=df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# ### 1. Locality

# %%
analyze_column(df, 'locality')
# Out:
# Analysis for column 'locality':
# Number of NaN values: 0
# Number of unique values: 2099
# Percentage of NaN values: 0.00%
# Percentage of unique values: 13.64%
# Unique values: ['Ham' 'Putte' 'IVOZ-RAMET' ... 'MONT-SAINTE-ALDEGONDE' 'Louveigné'
#  'GrÃce-Hollogne']

# %%
df['locality'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15393 entries, 0 to 16753
# Series name: locality
# Non-Null Count  Dtype
# --------------  -----
# 15393 non-null  object
# dtypes: object(1)
# memory usage: 240.5+ KB

# %%
list_cities = df['locality'].unique()

# %%
# USING OPENCAGE to get longitude and latitude
# from opencage.geocoder import OpenCageGeocode
# key = "8adf7c226ce340589f05518e1cb51450"
# geocoder = OpenCageGeocode(key)

# latitudes = []
# longitudes = []

# for address in list_cities:
# 	result = geocoder.geocode(address, no_annotations="1")

# 	if result and len(result):
# 		longitude = result[0]['geometry']['lng']
# 		latitude = result[0]['geometry']['lat']
# 	else:
# 		longitude = "N/A"
# 		latitude = "N/A"

# 	with open('data/longlat.csv', 'a') as f:
# 		f.write(address)
# 		f.write(',')
# 		f.write(str(latitude)),
# 		f.write(',')
# 		f.write(str(longitude))
# 		f.write('\n')

# %%
# add columns w longitude latitude
df_ll = pd.read_csv('data/longlat.csv', on_bad_lines='skip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 2
#       1 # add columns w longitude latitude
# ----> 2 df_ll = pd.read_csv('data/longlat.csv', on_bad_lines='skip')
#
# File ~/Desktop/GitHub Projects/ImmoElizaDataAnalysis/.env/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/GitHub Projects/ImmoElizaDataAnalysis/.env/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/Desktop/GitHub Projects/ImmoElizaDataAnalysis/.env/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/GitHub Projects/ImmoElizaDataAnalysis/.env/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/Desktop/GitHub Projects/ImmoElizaDataAnalysis/.env/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/longlat.csv'

# %%
df_ll
# Out:
#                       locality   latitude  longitude
# 0                          Ham  49.746322   3.073303
# 1                        Putte  51.057082   4.631047
# 2                   IVOZ-RAMET  50.582277   5.452349
# 3                      Herstal  50.665041   5.629981
# 4                        Liege  50.645094   5.573611
# ...                        ...        ...        ...
# 2396                   Petigny  50.058382   4.532427
# 2397        Zwijndrecht Burcht  51.202805   4.341636
# 2398          Liege (Bressoux)  50.641296   5.611144
# 2399          FONTAINE-VALMONT  50.320469   4.213974
# 2400  Geraardsbergen Ophasselt  50.821858   3.897035
#
# [2401 rows x 3 columns]

# %%
# get all the long and lat values in the DF datafram
df = pd.merge(df, df_ll)
df['longitude'].replace('N/A', np.nan, inplace=True)
df['latitude'].replace('N/A', np.nan, inplace=True)

df = df.dropna(subset=['longitude', 'latitude'])

# %% [markdown]
# ### 2. Property Type

# %%
analyze_column(df, 'property_type')
# Out:
# Analysis for column 'property_type':
# Number of NaN values: 0
# Number of unique values: 2
# Percentage of NaN values: 0.00%
# Percentage of unique values: 0.01%
# Unique values: ['HOUSE' 'APARTMENT']

# %%
# No NaN Values
df['property_type'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 15284 entries, 0 to 15283
# Series name: property_type
# Non-Null Count  Dtype
# --------------  -----
# 15284 non-null  object
# dtypes: object(1)
# memory usage: 119.5+ KB

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'region', y = 'price',  data = df,ax=ax, hue='property_type')
plt.title('Region vs Price')
plt.xlabel('Region in Belgium')
plt.ylabel('Price (in million)')
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ### 3. Property Subtype

# %%
analyze_column(df, 'property_subtype')
# Out:
# Analysis for column 'property_subtype':
# Number of NaN values: 0
# Number of unique values: 23
# Percentage of NaN values: 0.00%
# Percentage of unique values: 0.15%
# Unique values: ['VILLA' 'HOUSE' 'MANOR_HOUSE' 'DUPLEX' 'FARMHOUSE' 'APARTMENT'
#  'APARTMENT_BLOCK' 'MIXED_USE_BUILDING' 'TOWN_HOUSE'
#  'EXCEPTIONAL_PROPERTY' 'BUNGALOW' 'MANSION' 'COUNTRY_COTTAGE'
#  'FLAT_STUDIO' 'CHALET' 'GROUND_FLOOR' 'PENTHOUSE' 'SERVICE_FLAT'
#  'TRIPLEX' 'LOFT' 'OTHER_PROPERTY' 'KOT' 'CASTLE']

# %%
df['property_subtype'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 15284 entries, 0 to 15283
# Series name: property_subtype
# Non-Null Count  Dtype
# --------------  -----
# 15284 non-null  object
# dtypes: object(1)
# memory usage: 119.5+ KB

# %%
plt.xticks(rotation=90)
sns.histplot(df, x='property_subtype')
# Out:
# <Axes: xlabel='property_subtype', ylabel='Count'>

# %%
# Sort the boxplot graphs on mean pricing (ascending)
mean_prices = df.groupby('property_subtype')['price'].mean().sort_values(ascending=True)
sorted_categories = mean_prices.index.tolist()
df['property_subtype'] = pd.Categorical(df['property_subtype'], categories=sorted_categories, ordered=True)

#creating the boxplot per property subtype
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'property_subtype', y = 'price',  data = df,ax=ax)
plt.title('Property subtype vs Price')
plt.xlabel('Property subtype')
plt.ylabel('Price (in million)')
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ### 4. Number of Rooms

# %%
analyze_column(df, 'number_rooms')
# Out:
# Analysis for column 'number_rooms':
# Number of NaN values: 0
# Number of unique values: 22
# Percentage of NaN values: 0.00%
# Percentage of unique values: 0.14%
# Unique values: [ 4.  3. 10.  5.  2.  6.  7.  8.  1. 13.  0.  9. 16. 12. 11. 18. 60. 17.
#  25. 15. 21. 46.]

# %%
df['number_rooms'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 15284 entries, 0 to 15283
# Series name: number_rooms
# Non-Null Count  Dtype
# --------------  -----
# 15284 non-null  float64
# dtypes: float64(1)
# memory usage: 119.5 KB

# %%
sns.boxplot(x=df['number_rooms'])
# Out:
# <Axes: xlabel='number_rooms'>

# %%
df_num_rooms = df[df['number_rooms'] <= 20]

sns.histplot(df_num_rooms, x='number_rooms', bins = 10)
# Good metric would be to use num_rooms up to 20
# Out:
# <Axes: xlabel='number_rooms', ylabel='Count'>

# %%
# Need to remove outlyers to get good normal distribution (using IQR method)
df = remove_outliers_iqr(df, 'number_rooms')
sns.boxplot(x=df['number_rooms'])
# Out:
# <Axes: xlabel='number_rooms'>

# %%
sns.histplot(x=df['number_rooms'])
plt.title('Histogram - number of rooms')
# Out:
# Text(0.5, 1.0, 'Histogram - number of rooms')

# %%
sns.regplot(df, x='number_rooms', y='price', scatter_kws = {"color": "blue", "alpha": 0.2},
            line_kws = {"color": "red"})
plt.title('Price vs Number of rooms')
#  5.8200e+02 1.1090e+03 6.9100e+02 3.5900e+02 3.9500e+02 4.6200e+02
#  5.5400e+02 3.8900e+02 4.2800e+02 4.0300e+02 5.1000e+02 4.4900e+02
#  7.3700e+02 4.0900e+02 4.5800e+02 6.4000e+02 8.6800e+02]

# %%
# Theres quite a bit of Nan Values (5.41%)- checking these out 
#(we could backfill the NaN values with the mean of the Living_ area per property_subtype)
df[df['living_area'].isna()]
# Out:
#             locality property_type    property_subtype     price  \
# 32             Putte         HOUSE               HOUSE  649000.0
# 39        IVOZ-RAMET         HOUSE               HOUSE  155000.0
# 42           Herstal         HOUSE     APARTMENT_BLOCK  425000.0
# 84           Herstal         HOUSE               HOUSE  245000.0
# 118            Liege         HOUSE  MIXED_USE_BUILDING  235000.0
# ...              ...           ...                 ...       ...
# 15160  Bellefontaine         HOUSE               HOUSE  499000.0
# 15223        LUINGNE         HOUSE     COUNTRY_COTTAGE  500000.0
# 15234        Mormont         HOUSE               HOUSE  220000.0
# 15242       St-Kruis         HOUSE               HOUSE  380000.0
# 15258         SEPTON         HOUSE               HOUSE  450000.0
#
#        number_rooms  living_area         kitchen furnished  fireplace terrace  \
# 32              3.0          NaN  HYPER_EQUIPPED       NaN        1.0    True
# 39              3.0          NaN             NaN       NaN       -1.0    True
# 42              5.0          NaN               0       NaN        NaN    True
# 84              4.0          NaN               0       NaN       -1.0    True
# 118             0.0          NaN               0       NaN        NaN     NaN
# ...             ...          ...             ...       ...        ...     ...
# 15160           4.0          NaN   SEMI_EQUIPPED       NaN        1.0    True
# 15223           7.0          NaN               0       NaN       -1.0    True
# 15234           4.0          NaN       INSTALLED       NaN        NaN     NaN
# 15242           3.0          NaN       INSTALLED     False        NaN     NaN
# 15258           3.0          NaN             NaN       NaN       -1.0    True
#
#        ...  garden garden_area  surface_land number_facades swimming_pool  \
# 32     ...    True       512.0           512              4          True
# 39     ...     NaN         NaN            70              2           NaN
# 42     ...     NaN         NaN             0              2           NaN
# 84     ...    True       500.0           916              3           NaN
# 118    ...     NaN         NaN             0              2           NaN
# ...    ...     ...         ...           ...            ...           ...
# 15160  ...     NaN         NaN           900              3          True
# 15223  ...     NaN         NaN          2086              4           NaN
# 15234  ...     NaN         NaN          2170              4           NaN
# 15242  ...     NaN         NaN           454              3           NaN
# 15258  ...     NaN         NaN          1639              4           NaN
#
#       building_state    region       province   latitude  longitude
# 32            AS_NEW  Flanders        Antwerp  51.057082   4.631047
# 39       TO_RENOVATE  Wallonie          Liège  50.582277   5.452349
# 42              GOOD  Wallonie          Liège  50.665041   5.629981
# 84     TO_BE_DONE_UP  Wallonie          Liège  50.665041   5.629981
# 118             GOOD  Wallonie          Liège  50.645094   5.573611
# ...              ...       ...            ...        ...        ...
# 15160  TO_BE_DONE_UP  Wallonie     Luxembourg  48.015172   6.443377
# 15223           GOOD  Wallonie        Hainaut  50.738394   3.233738
# 15234           GOOD  Wallonie     Luxembourg  50.326333   5.592465
# 15242         AS_NEW  Flanders  West Flanders  51.214202   3.250651
# 15258            NaN  Wallonie     Luxembourg  50.360101   5.437417
#
# [871 rows x 21 columns]

# %%
# backfill the NaN values with the mean of the Living_area per property_subtype
mean_living_area = df.groupby('property_subtype')['living_area'].transform('mean')
#  Transform function is used to calculate the mean living area for each property subtype.

# %%
mean_living_area = df.groupby('property_subtype')['living_area'].transform('mean')
filled_nan_living_area = df.groupby('property_subtype')['living_area'].fillna(round(mean_living_area))
df['living_area'] = filled_nan_living_area

# %%
df[df['living_area'].isna()]
# Out:
# Empty DataFrame
# Columns: [locality, property_type, property_subtype, price, number_rooms, living_area, kitchen, furnished, fireplace, terrace, terrace_area, garden, garden_area, surface_land, number_facades, swimming_pool, building_state, region, province, latitude, longitude]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_living_area = df[df['living_area'] <= 600]
sns.displot(df_living_area, x='living_area', bins=1000, kde=True)

# %%
# Visualise and Remove the outlyers
sns.boxplot(x=df['living_area'])
# Out:
# <Axes: xlabel='living_area'>

# %%
df = remove_outliers_iqr(df, 'living_area')
sns.boxplot(x=df['living_area'])
# Out:
# <Axes: xlabel='living_area'>

# %%
sns.displot(x=df['living_area'], kde=True)
plt.title('Histogram - Living Area')
# Out:
# Text(0.5, 1.0, 'Histogram - Living Area')

# %% [markdown]
# ### 6. Kitchen

# %%
df['kitchen'].unique()
# Out:
# array(['INSTALLED', 'HYPER_EQUIPPED', 'NOT_INSTALLED', '0',
#        'SEMI_EQUIPPED', 'USA_HYPER_EQUIPPED', nan, 'USA_INSTALLED',
#        'USA_SEMI_EQUIPPED', 'USA_UNINSTALLED'], dtype=object)

# %%
df[df['kitchen'].isna()]
# TODO: We have a lot of NaN values - What to do with these?
# Out:
#               locality property_type property_subtype     price  number_rooms  \
# 39          IVOZ-RAMET         HOUSE            HOUSE  155000.0           3.0
# 51             Herstal         HOUSE  APARTMENT_BLOCK  283000.0           3.0
# 66             Herstal         HOUSE  APARTMENT_BLOCK  249000.0           7.0
# 80             Herstal         HOUSE            HOUSE  139500.0           3.0
# 89             Herstal         HOUSE            HOUSE  219000.0           4.0
# ...                ...           ...              ...       ...           ...
# 15254  Flémalle-Grande         HOUSE            HOUSE  239000.0           2.0
# 15258           SEPTON         HOUSE            HOUSE  450000.0           3.0
# 15262            Angre         HOUSE            HOUSE   49000.0           1.0
# 15267        Haut-fays         HOUSE            HOUSE  239000.0           7.0
# 15283            Haren         HOUSE            HOUSE  550000.0           3.0
#
#        living_area kitchen furnished  fireplace terrace  ...  garden  \
# 39           183.0     NaN       NaN       -1.0    True  ...     NaN
# 51           164.0     NaN       NaN        NaN    True  ...     NaN
# 66           232.0     NaN       NaN       -1.0     NaN  ...     NaN
# 80            90.0     NaN     False        NaN     NaN  ...    True
# 89           171.0     NaN     False        NaN    True  ...    True
# ...            ...     ...       ...        ...     ...  ...     ...
# 15254        120.0     NaN       NaN       -1.0     NaN  ...    True
# 15258        183.0     NaN       NaN       -1.0    True  ...     NaN
# 15262         65.0     NaN       NaN        NaN     NaN  ...     NaN
# 15267        158.0     NaN     False        NaN    True  ...    True
# 15283        180.0     NaN     False        1.0    True  ...     NaN
#
#       garden_area  surface_land number_facades swimming_pool building_state  \
# 39            NaN            70              2           NaN    TO_RENOVATE
# 51            NaN             0              2         False  TO_BE_DONE_UP
# 66            NaN           779              2           NaN            NaN
# 80           30.0            66              2         False    TO_RENOVATE
# 89          541.0           706              3           NaN           GOOD
# ...           ...           ...            ...           ...            ...
# 15254       370.0           430              3           NaN            NaN
# 15258         NaN          1639              4           NaN            NaN
# 15262         NaN           916              4           NaN    TO_RENOVATE
# 15267       166.0           266              4           NaN           GOOD
# 15283         NaN             0            NaN         False           GOOD
#
#          region    province   latitude  longitude
# 39     Wallonie       Liège  50.582277   5.452349
# 51     Wallonie       Liège  50.665041   5.629981
# 66     Wallonie       Liège  50.665041   5.629981
# 80     Wallonie       Liège  50.665041   5.629981
# 89     Wallonie       Liège  50.665041   5.629981
# ...         ...         ...        ...        ...
# 15254  Wallonie       Liège  50.615394   5.473085
# 15258  Wallonie  Luxembourg  50.360101   5.437417
# 15262  Wallonie     Hainaut  50.366983   3.695451
# 15267  Wallonie  Luxembourg  50.001171   5.016915
# 15283  Brussels    Brussels  52.790562   7.240027
#
# [1419 rows x 21 columns]

# %%
df[df['kitchen'] == '0']
# need to change this '0' to NOT_DEFINED - NOT CERTAIN but probably when filling out the survey of the listing the operator filled out 0 in a lot of cases
# To not assume it's installed or not installed we will make a new category - NOT_DEFINED
df['kitchen'].replace('0', 'NOT_DEFINED', inplace=True)
df[df['kitchen'] == 'NOT_DEFINED']
# Out:
#                  locality property_type    property_subtype     price  \
# 10                    Ham     APARTMENT              DUPLEX  245000.0
# 20                  Putte         HOUSE               HOUSE  589000.0
# 23                  Putte         HOUSE               HOUSE  393000.0
# 30                  Putte     APARTMENT           APARTMENT  285000.0
# 41                Herstal         HOUSE               HOUSE  225000.0
# ...                   ...           ...                 ...       ...
# 15248            HOUWAART         HOUSE               HOUSE  550000.0
# 15270            VELAINES         HOUSE               HOUSE  450000.0
# 15271  Zwijndrecht Burcht         HOUSE               HOUSE  170000.0
# 15272    Liege (Bressoux)         HOUSE  MIXED_USE_BUILDING  171000.0
# 15282  Sint-Martens-Latem         HOUSE               HOUSE  885000.0
#
#        number_rooms  living_area      kitchen furnished  fireplace terrace  \
# 10              2.0        104.0  NOT_DEFINED     False        NaN     NaN
# 20              4.0        261.0  NOT_DEFINED       NaN        NaN     NaN
# 23              3.0        159.0  NOT_DEFINED       NaN        1.0    True
# 30              2.0         85.0  NOT_DEFINED     False        NaN     NaN
# 41              2.0         81.0  NOT_DEFINED       NaN       -1.0    True
# ...             ...          ...          ...       ...        ...     ...
# 15248           3.0        190.0  NOT_DEFINED       NaN       -1.0    True
# 15270           3.0        331.0  NOT_DEFINED       NaN       -1.0    True
# 15271           2.0        140.0  NOT_DEFINED       NaN        NaN     NaN
# 15272           4.0        166.0  NOT_DEFINED       NaN        NaN     NaN
# 15282           2.0        236.0  NOT_DEFINED       NaN        NaN    True
#
#        ...  garden garden_area  surface_land number_facades swimming_pool  \
# 10     ...     NaN         NaN           NaN              3         False
# 20     ...     NaN         NaN           523            NaN         False
# 23     ...    True       300.0           712              4         False
# 30     ...     NaN         NaN           NaN              2           NaN
# 41     ...    True       104.0           225              3           NaN
# ...    ...     ...         ...           ...            ...           ...
# 15248  ...    True       333.0           413              3           NaN
# 15270  ...     NaN         NaN          1740              4           NaN
# 15271  ...     NaN         NaN           190              2           NaN
# 15272  ...     NaN         NaN             0              3         False
# 15282  ...     NaN         NaN           402              3           NaN
#
#        building_state    region         province   latitude  longitude
# 10               GOOD  Flanders          Limburg  49.746322   3.073303
# 20                NaN  Flanders          Antwerp  51.057082   4.631047
# 23                NaN  Flanders          Antwerp  51.057082   4.631047
# 30             AS_NEW  Flanders          Antwerp  51.057082   4.631047
# 41     JUST_RENOVATED  Wallonie            Liège  50.665041   5.629981
# ...               ...       ...              ...        ...        ...
# 15248             NaN  Flanders  Flemish Brabant  50.932981   4.859555
# 15270             NaN  Wallonie          Hainaut  48.703359   5.300107
# 15271     TO_RENOVATE  Flanders          Antwerp  51.202805   4.341636
# 15272            GOOD  Wallonie            Liège  50.641296   5.611144
# 15282            GOOD  Flanders    East Flanders  51.020971   3.639755
#
# [2521 rows x 21 columns]

# %%
create_cat_plot(df, 'kitchen', 90)

# %%
sns.histplot(df, x='kitchen')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'INSTALLED'),
#   Text(1, 0, 'HYPER_EQUIPPED'),
#   Text(2, 0, 'NOT_INSTALLED'),
#   Text(3, 0, 'NOT_DEFINED'),
#   Text(4, 0, 'SEMI_EQUIPPED'),
#   Text(5, 0, 'USA_HYPER_EQUIPPED'),
#   Text(6, 0, 'USA_INSTALLED'),
#   Text(7, 0, 'USA_SEMI_EQUIPPED'),
#   Text(8, 0, 'USA_UNINSTALLED')])

# %%
df['kitchen'].describe()
# Out:
# count         13163
# unique            9
# top       INSTALLED
# freq           5285
# Name: kitchen, dtype: object

# %%
df[df['kitchen'].isna()]
# Out:
#               locality property_type property_subtype     price  number_rooms  \
# 39          IVOZ-RAMET         HOUSE            HOUSE  155000.0           3.0
# 51             Herstal         HOUSE  APARTMENT_BLOCK  283000.0           3.0
# 66             Herstal         HOUSE  APARTMENT_BLOCK  249000.0           7.0
# 80             Herstal         HOUSE            HOUSE  139500.0           3.0
# 89             Herstal         HOUSE            HOUSE  219000.0           4.0
# ...                ...           ...              ...       ...           ...
# 15254  Flémalle-Grande         HOUSE            HOUSE  239000.0           2.0
# 15258           SEPTON         HOUSE            HOUSE  450000.0           3.0
# 15262            Angre         HOUSE            HOUSE   49000.0           1.0
# 15267        Haut-fays         HOUSE            HOUSE  239000.0           7.0
# 15283            Haren         HOUSE            HOUSE  550000.0           3.0
#
#        living_area kitchen furnished  fireplace terrace  ...  garden  \
# 39           183.0     NaN       NaN       -1.0    True  ...     NaN
# 51           164.0     NaN       NaN        NaN    True  ...     NaN
# 66           232.0     NaN       NaN       -1.0     NaN  ...     NaN
# 80            90.0     NaN     False        NaN     NaN  ...    True
# 89           171.0     NaN     False        NaN    True  ...    True
# ...            ...     ...       ...        ...     ...  ...     ...
# 15254        120.0     NaN       NaN       -1.0     NaN  ...    True
# 15258        183.0     NaN       NaN       -1.0    True  ...     NaN
# 15262         65.0     NaN       NaN        NaN     NaN  ...     NaN
# 15267        158.0     NaN     False        NaN    True  ...    True
# 15283        180.0     NaN     False        1.0    True  ...     NaN
#
#       garden_area  surface_land number_facades swimming_pool building_state  \
# 39            NaN            70              2           NaN    TO_RENOVATE
# 51            NaN             0              2         False  TO_BE_DONE_UP
# 66            NaN           779              2           NaN            NaN
# 80           30.0            66              2         False    TO_RENOVATE
# 89          541.0           706              3           NaN           GOOD
# ...           ...           ...            ...           ...            ...
# 15254       370.0           430              3           NaN            NaN
# 15258         NaN          1639              4           NaN            NaN
# 15262         NaN           916              4           NaN    TO_RENOVATE
# 15267       166.0           266              4           NaN           GOOD
# 15283         NaN             0            NaN         False           GOOD
#
#          region    province   latitude  longitude
# 39     Wallonie       Liège  50.582277   5.452349
# 51     Wallonie       Liège  50.665041   5.629981
# 66     Wallonie       Liège  50.665041   5.629981
# 80     Wallonie       Liège  50.665041   5.629981
# 89     Wallonie       Liège  50.665041   5.629981
# ...         ...         ...        ...        ...
# 15254  Wallonie       Liège  50.615394   5.473085
# 15258  Wallonie  Luxembourg  50.360101   5.437417
# 15262  Wallonie     Hainaut  50.366983   3.695451
# 15267  Wallonie  Luxembourg  50.001171   5.016915
# 15283  Brussels    Brussels  52.790562   7.240027
#
# [1419 rows x 21 columns]

# %%
df['kitchen'].replace(np.nan, 'NOT_DEFINED', inplace=True)

# %%
df[df['kitchen'].isna()]
# Out:
# Empty DataFrame
# Columns: [locality, property_type, property_subtype, price, number_rooms, living_area, kitchen, furnished, fireplace, terrace, terrace_area, garden, garden_area, surface_land, number_facades, swimming_pool, building_state, region, province, latitude, longitude]
# Index: []
#
# [0 rows x 21 columns]

# %%
sns.histplot(df, x='kitchen')
plt.xticks(rotation=90)
plt.title('Type of kitchen - counts')
# Out:
# Text(0.5, 1.0, 'Type of kitchen - counts')

# %% [markdown]
# ### 7. Furnished

# %%
analyze_column(df, 'furnished')
# Out:
# Analysis for column 'furnished':
# Number of NaN values: 7559
# Number of unique values: 2
# Percentage of NaN values: 51.84%
# Percentage of unique values: 0.01%
# Unique values: [nan False True]

# %%
# A lot of NaN - can be assume that this NaN mean it is not furnished (I think so - especially Belgium not a lot of houses are sold furnished)
# replacing the NaN values with False
df['furnished'] = df['furnished'].replace(np.nan, False)

# replace the False values with 0 and the True values with 1
df['furnished'].replace(False, 0, inplace=True)
df['furnished'].replace(True, 1, inplace=True)

# %%
df[df['furnished'].isna()]
# Out:
# Empty DataFrame
# Columns: [locality, property_type, property_subtype, price, number_rooms, living_area, kitchen, furnished, fireplace, terrace, terrace_area, garden, garden_area, surface_land, number_facades, swimming_pool, building_state, region, province, latitude, longitude]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['furnished'].unique()
# Out:
# array([0, 1])

# %%
df['furnished'].value_counts().plot(kind='bar')
plt.title('Furnished property - count')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ### 8. Fireplace

# %%
analyze_column(df, 'fireplace')
# Out:
# Analysis for column 'fireplace':
# Number of NaN values: 9940
# Number of unique values: 6
# Percentage of NaN values: 68.17%
# Percentage of unique values: 0.04%
# Unique values: [-1. nan  1.  2.  3.  4. 10.]

# %%
df['fireplace'].unique()
# Out:
# array([-1., nan,  1.,  2.,  3.,  4., 10.])

# %%
# ASSUMPTION 1: -1 means there is no fireplace
df[df['fireplace'] == -1]
# Out:
#                locality property_type property_subtype     price  \
# 0                   Ham         HOUSE            VILLA  429500.0
# 6                   Ham         HOUSE            HOUSE  295000.0
# 9                   Ham         HOUSE            VILLA  549000.0
# 12                Putte         HOUSE            HOUSE  599000.0
# 15                Putte         HOUSE            HOUSE  375000.0
# ...                 ...           ...              ...       ...
# 15254   Flémalle-Grande         HOUSE            HOUSE  239000.0
# 15258            SEPTON         HOUSE            HOUSE  450000.0
# 15270          VELAINES         HOUSE            HOUSE  450000.0
# 15273  FONTAINE-VALMONT         HOUSE            HOUSE  175000.0
# 15275             Havré         HOUSE            HOUSE  120000.0
#
#        number_rooms  living_area        kitchen  furnished  fireplace terrace  \
# 0               4.0        215.0      INSTALLED          0       -1.0     NaN
# 6               3.0        165.0      INSTALLED          0       -1.0     NaN
# 9               5.0        351.0      INSTALLED          0       -1.0     NaN
# 12              5.0        167.0      INSTALLED          0       -1.0    True
# 15              3.0        172.0      INSTALLED          0       -1.0     NaN
# ...             ...          ...            ...        ...        ...     ...
# 15254           2.0        120.0    NOT_DEFINED          0       -1.0     NaN
# 15258           3.0        183.0    NOT_DEFINED          0       -1.0    True
# 15270           3.0        331.0    NOT_DEFINED          0       -1.0    True
# 15273           2.0        125.0  SEMI_EQUIPPED          0       -1.0     NaN
# 15275           2.0         90.0  SEMI_EQUIPPED          0       -1.0    True
#
#        ...  garden garden_area  surface_land number_facades swimming_pool  \
# 0      ...    True         NaN          1472              4           NaN
# 6      ...    True         NaN           457              3           NaN
# 9      ...    True         NaN             0              4           NaN
# 12     ...    True        95.0           416              4           NaN
# 15     ...     NaN         NaN           705              4           NaN
# ...    ...     ...         ...           ...            ...           ...
# 15254  ...    True       370.0           430              3           NaN
# 15258  ...     NaN         NaN          1639              4           NaN
# 15270  ...     NaN         NaN          1740              4           NaN
# 15273  ...     NaN         NaN          3940              2           NaN
# 15275  ...     NaN         NaN           273              3           NaN
#
#        building_state    region    province   latitude  longitude
# 0                GOOD  Flanders     Limburg  49.746322   3.073303
# 6      JUST_RENOVATED  Flanders     Limburg  49.746322   3.073303
# 9                GOOD  Flanders     Limburg  49.746322   3.073303
# 12     JUST_RENOVATED  Flanders     Antwerp  51.057082   4.631047
# 15               GOOD  Flanders     Antwerp  51.057082   4.631047
# ...               ...       ...         ...        ...        ...
# 15254             NaN  Wallonie       Liège  50.615394   5.473085
# 15258             NaN  Wallonie  Luxembourg  50.360101   5.437417
# 15270             NaN  Wallonie     Hainaut  48.703359   5.300107
# 15273  JUST_RENOVATED  Wallonie     Hainaut  50.320469   4.213974
# 15275   TO_BE_DONE_UP  Wallonie     Hainaut  50.460573   4.037512
#
# [3877 rows x 21 columns]

# %%
# Replace the -1 values with 0
df['fireplace'].replace(-1, 0, inplace=True)

# %%
# ASSUMPTION 2 : -1 means there is no fireplace
# Replace the NaN values with 0
df['fireplace'].replace(np.nan, 0, inplace=True)

# %%
df['fireplace'].unique()
# Out:
# array([ 0.,  1.,  2.,  3.,  4., 10.])

# %%
sns.catplot(data=df,x='fireplace',y='price',
               size=4.5,aspect=1.35, hue='region')
plt.title('fireplace vs Price - per Region')
# Out:
# Text(0.5, 1.0, 'fireplace vs Price - per Region')

# %%
df['fireplace'].unique()
# Out:
# array([ 0.,  1.,  2.,  3.,  4., 10.])

# %%
sns.boxplot(x =df['fireplace'])
# Out:
# <Axes: xlabel='fireplace'>

# %%
# Remove outlyers (all 2 up to 10 - 8 entries)
df[df['fireplace'] >= 2]
# Out:
#              locality property_type      property_subtype     price  \
# 973    Geraardsbergen         HOUSE                 HOUSE  245000.0
# 1255         Maldegem         HOUSE                 VILLA  470000.0
# 1590          Beersel         HOUSE                 VILLA  650000.0
# 2640         Nivelles         HOUSE  EXCEPTIONAL_PROPERTY  600000.0
# 2708            Namur         HOUSE                 VILLA  365000.0
# 2803             Gent         HOUSE  EXCEPTIONAL_PROPERTY  548000.0
# 5365            Ronse         HOUSE                 HOUSE   99000.0
# 6044            Essen         HOUSE       COUNTRY_COTTAGE  875000.0
# 10180          Tubize         HOUSE                 VILLA  375000.0
# 10288       Templeuve         HOUSE  EXCEPTIONAL_PROPERTY  550000.0
# 11356      Bassevelde         HOUSE       COUNTRY_COTTAGE  695000.0
# 12460      Kortenaken         HOUSE                 VILLA  480000.0
# 12694         Enghien         HOUSE                 HOUSE  590000.0
# 12887          Bilzen         HOUSE                 HOUSE  279000.0
# 13399      RACHECOURT         HOUSE                 HOUSE  269000.0
# 14532         Rillaar         HOUSE                 HOUSE  430000.0
#
#        number_rooms  living_area         kitchen  furnished  fireplace  \
# 973             3.0        183.0       INSTALLED          0        2.0
# 1255            6.0        327.0       INSTALLED          0        2.0
# 1590            4.0        242.0       INSTALLED          0        2.0
# 2640            3.0        244.0       INSTALLED          0        2.0
# 2708            2.0        120.0   SEMI_EQUIPPED          0        2.0
# 2803            3.0        128.0       INSTALLED          0        3.0
# 5365            2.0        183.0     NOT_DEFINED          0        4.0
# 6044            4.0        258.0       INSTALLED          0        2.0
# 10180           3.0        180.0       INSTALLED          0        2.0
# 10288           5.0        315.0     NOT_DEFINED          0        2.0
# 11356           4.0        296.0       INSTALLED          0        2.0
# 12460           5.0        350.0       INSTALLED          0        2.0
# 12694           4.0        260.0  HYPER_EQUIPPED          0        2.0
# 12887           3.0        218.0       INSTALLED          0        2.0
# 13399           3.0        123.0     NOT_DEFINED          0       10.0
# 14532           3.0        194.0     NOT_DEFINED          0        2.0
#
#       terrace  ...  garden garden_area  surface_land number_facades  \
# 973       NaN  ...     NaN         NaN           100              3
# 1255     True  ...     NaN         NaN           738              4
# 1590     True  ...    True      3400.0          3600              4
# 2640     True  ...    True      3558.0          3718              4
# 2708     True  ...    True         1.0           908              4
# 2803     True  ...     NaN         NaN           127              2
# 5365      NaN  ...    True         NaN           488              3
# 6044     True  ...    True      4500.0          5978              4
# 10180    True  ...    True       180.0           395              4
# 10288    True  ...     NaN         NaN          6255              4
# 11356     NaN  ...    True       350.0         23417              4
# 12460    True  ...    True         1.0          1900              4
# 12694    True  ...    True         1.0             0              2
# 12887     NaN  ...    True         1.0           500              4
# 13399    True  ...    True         NaN           379              3
# 14532     NaN  ...    True         NaN           517              4
#
#       swimming_pool  building_state    region         province   latitude  \
# 973             NaN            GOOD  Flanders    East Flanders  50.771578
# 1255            NaN            GOOD  Flanders    East Flanders  51.208887
# 1590            NaN     TO_RENOVATE  Flanders  Flemish Brabant  50.747841
# 2640          False             NaN  Wallonie  Walloon Brabant  50.597688
# 2708          False  JUST_RENOVATED  Wallonie            Namur  50.466528
# 2803            NaN            GOOD  Flanders    East Flanders  51.053829
# 5365            NaN   TO_BE_DONE_UP  Flanders    East Flanders  50.752620
# 6044          False            GOOD  Flanders          Antwerp  51.458224
# 10180         False          AS_NEW  Wallonie  Walloon Brabant  50.693020
# 10288           NaN             NaN  Wallonie          Hainaut  50.532628
# 11356         False     TO_RENOVATE  Flanders    East Flanders  51.231192
# 12460         False            GOOD  Flanders  Flemish Brabant  50.906611
# 12694         False          AS_NEW  Wallonie          Hainaut  50.692820
# 12887         False          AS_NEW  Flanders          Limburg  50.870779
# 13399           NaN     TO_RENOVATE  Wallonie       Luxembourg  49.590313
# 14532           NaN  JUST_RENOVATED  Flanders  Flemish Brabant  50.975741
#
#        longitude
# 973     3.882729
# 1255    3.445221
# 1590    4.306527
# 2640    4.323585
# 2708    4.866189
# 2803    3.725012
# 5365    3.601448
# 6044    7.015817
# 10180   4.204696
# 10288   3.174054
# 11356   3.678995
# 12460   5.062294
# 12694   4.038373
# 12887   5.518109
# 13399   5.724814
# 14532   4.892865
#
# [16 rows x 21 columns]

# %%
df = df[df['fireplace'] < 2]
sns.catplot(data=df,x='fireplace',y='price',
               size=4.5,aspect=1.35, hue='region')
plt.title('fireplace vs Price - per Region')
# Out:
# Text(0.5, 1.0, 'fireplace vs Price - per Region')

# %% [markdown]
# ### 9. Terrace

# %%
analyze_column(df, 'terrace')
# Assumption that NaN values are 0 and True values are 1
# Out:
# Analysis for column 'terrace':
# Number of NaN values: 5058
# Number of unique values: 1
# Percentage of NaN values: 34.72%
# Percentage of unique values: 0.01%
# Unique values: [nan True]

# %%
df.replace(np.nan, 0, inplace=True)
df.replace(True, 1, inplace=True)

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x= 'terrace', y = 'price',  data = df,ax=ax, hue='region')
plt.title('Terrace vs Price')
plt.xlabel('Terrace')
plt.ylabel('Price (in million)')
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %%
sns.histplot(df['terrace'])
plt.title('Terrace count')
# Out:
# Text(0.5, 1.0, 'Terrace count')

# %% [markdown]
# ### 10. Terrace Area

# %%
analyze_column(df, 'terrace_area')
# Out:
# Analysis for column 'terrace_area':
# Number of NaN values: 0
# Number of unique values: 153
# Percentage of NaN values: 0.00%
# Percentage of unique values: 1.05%
# Unique values: [0.00e+00 2.00e+01 3.70e+01 3.00e+01 5.20e+01 3.50e+01 5.00e+00 1.30e+01
#  1.20e+01 9.00e+00 8.00e+01 5.40e+01 5.30e+01 4.00e+01 2.50e+01 5.84e+02
#  4.20e+01 3.40e+01 1.40e+01 1.10e+01 1.60e+01 1.80e+01 1.00e+01 2.90e+01
#  6.00e+01 1.00e+00 2.40e+02 2.20e+01 4.80e+01 1.90e+01 3.90e+01 3.20e+01
#  3.30e+01 3.26e+02 2.00e+00 6.50e+01 5.60e+01 2.70e+01 3.00e+00 5.50e+01
#  8.00e+00 1.50e+01 7.00e+00 6.80e+01 2.40e+01 3.60e+01 7.00e+01 8.80e+01
#  1.70e+01 4.50e+01 4.00e+00 5.00e+01 4.10e+01 4.30e+01 1.61e+02 8.10e+01
#  2.80e+01 2.30e+01 1.20e+02 7.50e+01 1.96e+02 6.00e+00 4.40e+01 3.80e+01
#  7.20e+01 5.70e+01 9.90e+01 1.00e+02 2.10e+01 1.08e+02 4.60e+01 5.10e+01
#  3.10e+01 1.07e+02 1.82e+02 8.90e+01 9.80e+01 6.20e+01 8.50e+01 6.40e+01
#  2.60e+01 1.12e+02 1.25e+02 2.00e+02 1.47e+02 1.23e+02 1.10e+02 9.20e+01
#  4.34e+02 6.10e+01 8.40e+01 8.30e+01 9.00e+01 4.70e+01 1.95e+02 5.80e+01
#  1.30e+02 1.80e+02 1.02e+02 9.50e+01 9.60e+01 8.20e+01 1.50e+02 8.70e+01
#  1.60e+02 7.80e+01 8.00e+02 4.90e+01 9.30e+01 6.63e+02 1.05e+02 8.60e+01
#  2.13e+02 1.40e+02 1.35e+02 1.11e+02 1.29e+02 2.20e+02 6.60e+01 3.00e+02
#  1.15e+02 6.30e+01 1.04e+02 7.30e+01 1.28e+02 1.27e+02 1.83e+02 6.70e+01
#  5.90e+01 1.32e+02 1.16e+02 1.70e+02 7.60e+01 2.36e+02 5.50e+02 1.34e+02
#  4.55e+02 1.22e+02 1.62e+03 7.70e+01 1.17e+02 1.44e+02 6.90e+01 1.13e+02
#  2.35e+02 1.75e+02 9.40e+01 2.25e+02 7.07e+02 1.21e+02 1.03e+02 1.31e+02
#  1.24e+02]

# %%
sns.boxplot(x=df['terrace_area'])
# Out:
# <Axes: xlabel='terrace_area'>

# %%
df.groupby('terrace')['terrace_area'].mean()
# Out:
# terrace
# 0     0.000000
# 1    16.436685
# Name: terrace_area, dtype: float64

# %%
df[df['terrace_area'] == 0.0]
# Out:
#                  locality property_type property_subtype     price  \
# 0                     Ham         HOUSE            VILLA  429500.0
# 1                     Ham         HOUSE            HOUSE  399500.0
# 2                     Ham         HOUSE            HOUSE  381000.0
# 3                     Ham         HOUSE            HOUSE  393500.0
# 4                     Ham         HOUSE            HOUSE  315000.0
# ...                   ...           ...              ...       ...
# 15273    FONTAINE-VALMONT         HOUSE            HOUSE  175000.0
# 15274               Havré         HOUSE            HOUSE  179000.0
# 15275               Havré         HOUSE            HOUSE  120000.0
# 15281  Sint-Martens-Latem         HOUSE            HOUSE  599000.0
# 15282  Sint-Martens-Latem         HOUSE            HOUSE  885000.0
#
#        number_rooms  living_area         kitchen  furnished  fireplace  \
# 0               4.0        215.0       INSTALLED          0        0.0
# 1               3.0        197.0  HYPER_EQUIPPED          0        0.0
# 2               3.0        197.0  HYPER_EQUIPPED          0        0.0
# 3               3.0        192.0  HYPER_EQUIPPED          0        0.0
# 4               3.0        197.0   NOT_INSTALLED          0        0.0
# ...             ...          ...             ...        ...        ...
# 15273           2.0        125.0   SEMI_EQUIPPED          0        0.0
# 15274           3.0        138.0       INSTALLED          0        0.0
# 15275           2.0         90.0   SEMI_EQUIPPED          0        0.0
# 15281           4.0        199.0  HYPER_EQUIPPED          0        0.0
# 15282           2.0        236.0     NOT_DEFINED          0        0.0
#
#        terrace  ...  garden  garden_area  surface_land number_facades  \
# 0            0  ...       1          0.0          1472              4
# 1            0  ...       0          0.0           461              3
# 2            0  ...       0          0.0           343              3
# 3            0  ...       0          0.0           392              3
# 4            0  ...       0          0.0           509              3
# ...        ...  ...     ...          ...           ...            ...
# 15273        0  ...       0          0.0          3940              2
# 15274        0  ...       0          0.0           110              2
# 15275        1  ...       0          0.0           273              3
# 15281        1  ...       0          0.0          1104              4
# 15282        1  ...       0          0.0           402              3
#
#       swimming_pool  building_state    region       province   latitude  \
# 0                 0            GOOD  Flanders        Limburg  49.746322
# 1                 0          AS_NEW  Flanders        Limburg  49.746322
# 2                 0          AS_NEW  Flanders        Limburg  49.746322
# 3                 0          AS_NEW  Flanders        Limburg  49.746322
# 4                 0          AS_NEW  Flanders        Limburg  49.746322
# ...             ...             ...       ...            ...        ...
# 15273             0  JUST_RENOVATED  Wallonie        Hainaut  50.320469
# 15274             0            GOOD  Wallonie        Hainaut  50.460573
# 15275             0   TO_BE_DONE_UP  Wallonie        Hainaut  50.460573
# 15281         False     TO_RENOVATE  Flanders  East Flanders  51.020971
# 15282             0            GOOD  Flanders  East Flanders  51.020971
#
#        longitude
# 0       3.073303
# 1       3.073303
# 2       3.073303
# 3       3.073303
# 4       3.073303
# ...          ...
# 15273   4.213974
# 15274   4.037512
# 15275   4.037512
# 15281   3.639755
# 15282   3.639755
#
# [8861 rows x 21 columns]

# %%
# need to remove the outlyers to get 'normal distribution'
df = remove_outliers_iqr(df, 'terrace_area')
sns.boxplot(x=df['terrace_area'])
# Out:
# <Axes: xlabel='terrace_area'>

# %%
sns.distplot(x=df['terrace_area'])
# Out:
# /tmp/ipykernel_25154/2516338998.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['terrace_area'])
# <Axes: ylabel='Density'>

# %% [markdown]
# ### 11. Garden

# %%
analyze_column(df, 'garden')
# Out:
# Analysis for column 'garden':
# Number of NaN values: 0
# Number of unique values: 2
# Percentage of NaN values: 0.00%
# Percentage of unique values: 0.01%
# Unique values: [1 0]

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'garden', y = 'price',  data = df,ax=ax, hue='region')
plt.title('Garden vs Price')
plt.xlabel('Garden')
plt.ylabel('Price (in million)')
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %% [markdown]
#
#  5.5600e+02 3.2440e+03 5.3500e+02 3.4200e+02 6.1700e+02 8.3000e+02
#  9.4100e+02 2.1900e+02 2.4100e+02 7.7200e+02 1.1150e+03 7.0900e+02
#  6.3300e+02 3.4500e+02 1.1410e+03 1.2800e+03 1.3820e+03 2.4500e+03
#  1.3790e+03 1.5880e+03 6.6900e+02 3.2800e+02 5.1000e+02 7.8700e+02
#  6.1300e+02 3.3700e+02 1.2140e+03 5.6000e+02 3.4160e+03 7.6000e+03
#  2.6260e+03 1.2080e+03 8.2800e+02 2.0460e+03 1.3720e+03 1.7220e+03
#  6.7200e+02 1.3940e+03 4.2700e+02 9.2200e+02 5.0800e+02 3.9900e+02
#  3.2900e+03 2.5140e+03 3.6300e+02 7.5500e+02 1.7240e+03 5.1600e+02
#  2.7600e+03 1.8690e+03 6.4300e+02 9.1800e+02 1.7300e+02 6.0400e+02
#  1.8500e+03 2.7220e+03 9.2800e+02 4.8900e+02 1.0030e+03 1.6440e+03
#  1.2700e+03 3.2750e+03 9.1500e+02 5.7800e+02 6.6600e+02 5.9300e+02
#  2.2840e+03 1.2850e+03 7.2400e+02 4.0000e+03 2.3750e+03 1.9800e+02
#  1.4140e+03 8.6000e+02 3.3470e+03 2.5100e+02 1.6600e+02 9.0800e+02
#  2.1850e+03 4.1800e+02 5.1540e+03 4.3600e+02]

# %%
sns.boxplot(x=df['garden_area'])
# Out:
# <Axes: xlabel='garden_area'>

# %%
# Cannot get rid of the outlyers ! Leave as is
# This Garden Area is highly unbalanced!!
clean = remove_outliers_iqr(df,'garden_area')
sns.boxplot(x=clean['garden_area'])
# Out:
# <Axes: xlabel='garden_area'>

# %% [markdown]
# ### 13. Surface of the Land

# %%
analyze_column(df, 'surface_land')
# Out:
# Analysis for column 'surface_land':
# Number of NaN values: 0
# Number of unique values: 1979
# Percentage of NaN values: 0.00%
# Percentage of unique values: 14.74%
# Unique values: ['1472' '461' '343' ... '3609' '5154' '3940']

# %%
df['surface_land'].replace('UNKNOWN', -1, inplace=True)

# %%
analyze_column(df, 'surface_land')
# Out:
# Analysis for column 'surface_land':
# Number of NaN values: 0
# Number of unique values: 1979
# Percentage of NaN values: 0.00%
# Percentage of unique values: 14.74%
# Unique values: ['1472' '461' '343' ... '3609' '5154' '3940']

# %%
df['surface_land'] = df['surface_land'].astype(int)

# %%
df['surface_land']
# Out:
# 0        1472
# 1         461
# 2         343
# 3         392
# 4         509
#          ...
# 15279     705
# 15280     517
# 15281    1104
# 15282     402
# 15283       0
# Name: surface_land, Length: 13427, dtype: int64

# %%
# change the '-1' (first to np.nan) to the mean_value of surface_land grouped by property_subtype
df['surface_land'].replace(-1, np.nan, inplace=True)
mean_surface_land = df.groupby('property_subtype')['surface_land'].transform('mean')
filled_surface_land = df.groupby('property_subtype')['surface_land'].fillna(mean_surface_land)
df['surface_land'] = filled_surface_land

# %%
sns.boxplot(x=df['surface_land'])
# Out:
# <Axes: xlabel='surface_land'>

# %%
# Remove outlyers
df = remove_outliers_iqr(df, 'surface_land')
sns.boxplot(x=df['surface_land'])
# Out:
# <Axes: xlabel='surface_land'>

# %%
sns.distplot(df['surface_land'])
# Out:
# /tmp/ipykernel_25154/654472208.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['surface_land'])
# <Axes: xlabel='surface_land', ylabel='Density'>

# %%
g = sns.FacetGrid(df, col="region", hue="property_type", height=4, aspect=1.5, palette='muted')
g.map(sns.regplot, "surface_land", "price", scatter_kws={"alpha": 0.5})
g.set_axis_labels("Surface of the land (m2)", "Price (million euros)")
g.add_legend()

# %% [markdown]
# ### 14. Number of Facades

# %%
analyze_column(df, 'number_facades')
# Out:
# Analysis for column 'number_facades':
# Number of NaN values: 0
# Number of unique values: 9
# Percentage of NaN values: 0.00%
# Percentage of unique values: 0.07%
# Unique values: ['3' '4' 0 '2' '1' 'UNKNOWN' '6' '14' '5']

# %%
df['number_facades'].replace('UNKNOWN', -1, inplace=True)

# %%
df[df['number_facades'].isnull()]
# Out:
# Empty DataFrame
# Columns: [locality, property_type, property_subtype, price, number_rooms, living_area, kitchen, furnished, fireplace, terrace, terrace_area, garden, garden_area, surface_land, number_facades, swimming_pool, building_state, region, province, latitude, longitude]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['number_facades'] = df['number_facades'].astype(int)

# %%
# check if any strings in the column
unique_values = df['number_facades'].unique()
string_values = [value for value in unique_values if isinstance(value, str)]

# %%
df['number_facades'].replace(-1, np.nan, inplace=True)

mean_facades = df.groupby('property_subtype')['number_facades'].transform('mean')
filled_facades = df.groupby('property_subtype')['number_facades'].fillna(round(mean_facades))
df['number_facades'] = filled_facades

# %%
df['number_facades'].unique()
# Out:
# array([ 3.,  4.,  0.,  2.,  1.,  6., 14.,  5.])

# %%
sns.scatterplot(df, x='number_facades', y='price')
# Out:
# <Axes: xlabel='number_facades', ylabel='price'>

# %%
sns.boxplot(x=df['number_facades'])
# Out:
# <Axes: xlabel='number_facades'>

# %%
# Remove outlyers 
df = remove_outliers_iqr(df, 'number_facades')
sns.boxplot(x=df['number_facades'])
# Out:
# <Axes: xlabel='number_facades'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9907 entries, 1 to 15282
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   locality          9907 non-null   object
#  1   property_type     9907 non-null   object
#  2   property_subtype  9907 non-null   category
#  3   price             9907 non-null   float64
#  4   number_rooms      9907 non-null   float64
#  5   living_area       9907 non-null   float64
#  6   kitchen           9907 non-null   object
#  7   furnished         9907 non-null   int64
#  8   fireplace         9907 non-null   float64
#  9   terrace           9907 non-null   int64
#  10  terrace_area      9907 non-null   float64
#  11  garden            9907 non-null   int64
#  12  garden_area       9907 non-null   float64
#  13  surface_land      9907 non-null   float64
#  14  number_facades    9907 non-null   float64
#  15  swimming_pool     9907 non-null   object
#  16  building_state    9907 non-null   object
#  17  region            9907 non-null   object
#  18  province          9907 non-null   object
#  19  latitude          9907 non-null   float64
#  20  longitude         9907 non-null   float64
# dtypes: category(1), float64(10), int64(3), object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# ### 15. Swimming Pool

# %%
analyze_column(df, 'swimming_pool')
# Out:
# Analysis for column 'swimming_pool':
# Number of NaN values: 0
# Number of unique values: 2
# Percentage of NaN values: 0.00%
# Percentage of unique values: 0.02%
# Unique values: [0 1]

# %%
# change False and True to 0 and 1
df['swimming_pool'].replace(False, 0, inplace=True)
df['swimming_pool'].replace(True, 1, inplace=True)
# Out:
# /tmp/ipykernel_25154/2644011061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['swimming_pool'].replace(False, 0, inplace=True)
# /tmp/ipykernel_25154/2644011061.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['swimming_pool'].replace(True, 1, inplace=True)

# %%
create_cat_plot(df, 'swimming_pool', 0)

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'swimming_pool', y = 'price',  data = df,ax=ax, hue='region')
plt.title('Swimming Pool vs Price')
plt.xlabel('Swimming Pool')
plt.ylabel('Price (in million)')
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %%
df['swimming_pool'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ### 16. Building State

# %%
analyze_column(df, 'building_state')
# Out:
# Analysis for column 'building_state':
# Number of NaN values: 0
# Number of unique values: 8
# Percentage of NaN values: 0.00%
# Percentage of unique values: 0.08%
# Unique values: ['AS_NEW' 'JUST_RENOVATED' 'GOOD' 'TO_RENOVATE' 'TO_BE_DONE_UP' 0
#  'TO_RESTORE' 'UNKNOWN']

# %%
create_cat_plot(df, 'building_state', 90)

# %%
df[df['building_state'] == 'UNKNOWN']
# Out:
#                  locality property_type property_subtype     price  \
# 549                 Liège         HOUSE            HOUSE  445000.0
# 688               Seraing         HOUSE            HOUSE  159000.0
# 737               Seraing     APARTMENT        APARTMENT  210000.0
# 749               Seraing         HOUSE            HOUSE  245000.0
# 977                Brugge     APARTMENT        APARTMENT  273900.0
# ...                   ...           ...              ...       ...
# 14853         Kruishoutem         HOUSE            HOUSE  395000.0
# 14896            HAMPTEAU         HOUSE            HOUSE  349000.0
# 15057  Barvaux-sur-Ourthe     APARTMENT           DUPLEX   99000.0
# 15058  Barvaux-sur-Ourthe     APARTMENT        APARTMENT   99000.0
# 15232             BARVAUX         HOUSE            HOUSE  199000.0
#
#        number_rooms  living_area        kitchen  furnished  fireplace  \
# 549             6.0        300.0  NOT_INSTALLED          0        0.0
# 688             2.0         95.0    NOT_DEFINED          0        0.0
# 737             3.0         97.0    NOT_DEFINED          0        0.0
# 749             3.0        135.0    NOT_DEFINED          0        0.0
# 977             2.0         97.0    NOT_DEFINED          0        0.0
# ...             ...          ...            ...        ...        ...
# 14853           4.0        245.0      INSTALLED          0        0.0
# 14896           5.0        183.0      INSTALLED          0        0.0
# 15057           2.0         94.0      INSTALLED          0        0.0
# 15058           2.0         80.0      INSTALLED          0        0.0
# 15232           2.0         77.0    NOT_DEFINED          0        0.0
#
#        terrace  ...  garden  garden_area  surface_land  number_facades  \
# 549          0  ...       0          0.0           0.0             2.0
# 688          1  ...       1          0.0         182.0             2.0
# 737          1  ...       0          0.0           0.0             2.0
# 749          1  ...       0          0.0         173.0             2.0
# 977          1  ...       0          0.0           0.0             2.0
# ...        ...  ...     ...          ...           ...             ...
# 14853        0  ...       0          0.0         150.0             2.0
# 14896        0  ...       1          0.0        1332.0             2.0
# 15057        0  ...       0          0.0           0.0             2.0
# 15058        0  ...       0          0.0           0.0             2.0
# 15232        0  ...       1          0.0         978.0             2.0
#
#        swimming_pool  building_state    region       province   latitude  \
# 549                0         UNKNOWN  Wallonie          Liège  50.645094
# 688                0         UNKNOWN  Wallonie          Liège  50.615238
# 737                0         UNKNOWN  Wallonie          Liège  50.615238
# 749                0         UNKNOWN  Wallonie          Liège  50.615238
# 977                0         UNKNOWN  Flanders  West Flanders  51.208553
# ...              ...             ...       ...            ...        ...
# 14853              0         UNKNOWN  Flanders  East Flanders  50.904824
# 14896              0         UNKNOWN  Wallonie     Luxembourg  50.257904
# 15057              0         UNKNOWN  Wallonie     Luxembourg  50.350609
# 15058              0         UNKNOWN  Wallonie     Luxembourg  50.350609
# 15232              0         UNKNOWN  Wallonie     Luxembourg  50.350609
#
#        longitude
# 549     5.573611
# 688     5.508944
# 737     5.508944
# 749     5.508944
# 977     3.226772
# ...          ...
# 14853   3.528180
# 14896   5.472902
# 15057   5.493284
# 15058   5.493284
# 15232   5.493284
#
# [214 rows x 21 columns]

# %%
df['building_state'].replace(0, 'UNKNOWN', inplace=True)
# Out:
# /tmp/ipykernel_25154/2321911779.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['building_state'].replace(0, 'UNKNOWN', inplace=True)

# %%
df['building_state'].unique()
# Out:
# array(['AS_NEW', 'JUST_RENOVATED', 'GOOD', 'TO_RENOVATE', 'TO_BE_DONE_UP',
#        'UNKNOWN', 'TO_RESTORE'], dtype=object)

# %%
create_cat_plot(df, 'building_state', 90)

# %% [markdown]
# # 2. WRITING CLEANED DATA TO CSV

# %%
df
# Out:
#                        locality property_type property_subtype     price  \
# 1                           Ham         HOUSE            HOUSE  399500.0
# 2                           Ham         HOUSE            HOUSE  381000.0
# 3                           Ham         HOUSE            HOUSE  393500.0
# 4                           Ham         HOUSE            HOUSE  315000.0
# 5                           Ham         HOUSE            HOUSE  305000.0
# ...                         ...           ...              ...       ...
# 15278  Geraardsbergen Ophasselt         HOUSE            HOUSE  449000.0
# 15279  Geraardsbergen Ophasselt         HOUSE            HOUSE  549000.0
# 15280  Geraardsbergen Ophasselt         HOUSE            HOUSE  449000.0
# 15281        Sint-Martens-Latem         HOUSE            HOUSE  599000.0
# 15282        Sint-Martens-Latem         HOUSE            HOUSE  885000.0
#
#        number_rooms  living_area         kitchen  furnished  fireplace  \
# 1               3.0        197.0  HYPER_EQUIPPED          0        0.0
# 2               3.0        197.0  HYPER_EQUIPPED          0        0.0
# 3               3.0        192.0  HYPER_EQUIPPED          0        0.0
# 4               3.0        197.0   NOT_INSTALLED          0        0.0
# 5               3.0        195.0   NOT_INSTALLED          0        0.0
# ...             ...          ...             ...        ...        ...
# 15278           3.0        168.0  HYPER_EQUIPPED          0        0.0
# 15279           3.0        180.0  HYPER_EQUIPPED          0        0.0
# 15280           3.0        168.0  HYPER_EQUIPPED          0        0.0
# 15281           4.0        199.0  HYPER_EQUIPPED          0        0.0
# 15282           2.0        236.0     NOT_DEFINED          0        0.0
#
#        terrace  ...  garden  garden_area  surface_land  number_facades  \
# 1            0  ...       0          0.0         461.0             3.0
# 2            0  ...       0          0.0         343.0             3.0
# 3            0  ...       0          0.0         392.0             3.0
# 4            0  ...       0          0.0         509.0             3.0
# 5            0  ...       0          0.0         453.0             3.0
# ...        ...  ...     ...          ...           ...             ...
# 15278        1  ...       1        150.0         480.0             3.0
# 15279        1  ...       1        200.0         705.0             4.0
# 15280        1  ...       1        200.0         517.0             3.0
# 15281        1  ...       0          0.0        1104.0             4.0
# 15282        1  ...       0          0.0         402.0             3.0
#
#        swimming_pool  building_state    region       province   latitude  \
# 1                  0          AS_NEW  Flanders        Limburg  49.746322
# 2                  0          AS_NEW  Flanders        Limburg  49.746322
# 3                  0          AS_NEW  Flanders        Limburg  49.746322
# 4                  0          AS_NEW  Flanders        Limburg  49.746322
# 5                  0          AS_NEW  Flanders        Limburg  49.746322
# ...              ...             ...       ...            ...        ...
# 15278              0          AS_NEW  Flanders  East Flanders  50.821858
# 15279              0          AS_NEW  Flanders  East Flanders  50.821858
# 15280              0          AS_NEW  Flanders  East Flanders  50.821858
# 15281              0     TO_RENOVATE  Flanders  East Flanders  51.020971
# 15282              0            GOOD  Flanders  East Flanders  51.020971
#
#        longitude
# 1       3.073303
# 2       3.073303
# 3       3.073303
# 4       3.073303
# 5       3.073303
# ...          ...
# 15278   3.897035
# 15279   3.897035
# 15280   3.897035
# 15281   3.639755
# 15282   3.639755
#
# [9907 rows x 21 columns]

# %%
#write to csv
df.drop_duplicates(inplace=True)
df.reset_index(inplace=True, drop=True)
df.to_csv('data/cleaned.csv')
# Out:
# /tmp/ipykernel_25154/3748319980.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                       locality property_type property_subtype     price  \
# 0                          Ham         HOUSE            HOUSE  399500.0
# 1                          Ham         HOUSE            HOUSE  381000.0
# 2                          Ham         HOUSE            HOUSE  393500.0
# 3                          Ham         HOUSE            HOUSE  315000.0
# 4                          Ham         HOUSE            HOUSE  305000.0
# ...                        ...           ...              ...       ...
# 9899  Geraardsbergen Ophasselt         HOUSE            HOUSE  449000.0
# 9900  Geraardsbergen Ophasselt         HOUSE            HOUSE  549000.0
# 9901  Geraardsbergen Ophasselt         HOUSE            HOUSE  449000.0
# 9902        Sint-Martens-Latem         HOUSE            HOUSE  599000.0
# 9903        Sint-Martens-Latem         HOUSE            HOUSE  885000.0
#
#       number_rooms  living_area         kitchen  furnished  fireplace  \
# 0              3.0        197.0  HYPER_EQUIPPED          0        0.0
# 1              3.0        197.0  HYPER_EQUIPPED          0        0.0
# 2              3.0        192.0  HYPER_EQUIPPED          0        0.0
# 3              3.0        197.0   NOT_INSTALLED          0        0.0
# 4              3.0        195.0   NOT_INSTALLED          0        0.0
# ...            ...          ...             ...        ...        ...
# 9899           3.0        168.0  HYPER_EQUIPPED          0        0.0
# 9900           3.0        180.0  HYPER_EQUIPPED          0        0.0
# 9901           3.0        168.0  HYPER_EQUIPPED          0        0.0
# 9902           4.0        199.0  HYPER_EQUIPPED          0        0.0
# 9903           2.0        236.0     NOT_DEFINED          0        0.0
#
#       terrace  ...  garden  garden_area  surface_land  number_facades  \
# 0           0  ...       0          0.0         461.0             3.0
# 1           0  ...       0          0.0         343.0             3.0
# 2           0  ...       0          0.0         392.0             3.0
# 3           0  ...       0          0.0         509.0             3.0
# 4           0  ...       0          0.0         453.0             3.0
# ...       ...  ...     ...          ...           ...             ...
# 9899        1  ...       1        150.0         480.0             3.0
# 9900        1  ...       1        200.0         705.0             4.0
# 9901        1  ...       1        200.0         517.0             3.0
# 9902        1  ...       0          0.0        1104.0             4.0
# 9903        1  ...       0          0.0         402.0             3.0
#
#       swimming_pool  building_state    region       province   latitude  \
# 0                 0          AS_NEW  Flanders        Limburg  49.746322
# 1                 0          AS_NEW  Flanders        Limburg  49.746322
# 2                 0          AS_NEW  Flanders        Limburg  49.746322
# 3                 0          AS_NEW  Flanders        Limburg  49.746322
# 4                 0          AS_NEW  Flanders        Limburg  49.746322
# ...             ...             ...       ...            ...        ...
# 9899              0          AS_NEW  Flanders  East Flanders  50.821858
# 9900              0          AS_NEW  Flanders  East Flanders  50.821858
# 9901              0          AS_NEW  Flanders  East Flanders  50.821858
# 9902              0     TO_RENOVATE  Flanders  East Flanders  51.020971
# 9903              0            GOOD  Flanders  East Flanders  51.020971
#
#       longitude
# 0      3.073303
# 1      3.073303
# 2      3.073303
# 3      3.073303
# 4      3.073303
# ...         ...
# 9899   3.897035
# 9900   3.897035
# 9901   3.897035
# 9902   3.639755
# 9903   3.639755
#
# [9904 rows x 21 columns]

# %% [markdown]
# # 3. VISUALISATION

# %% [markdown]
# ## 3.1 Heatmap

# %%
# create heatmap of the houses and prices according to function written in DrawHeatMap
from utils.DrawHeatmap import drawheatmap, drawfullmap
drawheatmap()

#Execute this if you want the full items and details
# Note! Takes a while to load :)
# drawfullmap()

# %% [markdown]
# #### Heatmap conclusion
# See the ''belgian_house_prices_heatmap.html' document that has been created in the root directory. Open up in browser.
#
# Very expensive housing in Brussels Centre / Ixelles / Uccle and Knokke Heist
# Other hotspots are around all the big cities (Gent / Antwerp / Charleroi / La Louvriere / Liege / Verviers)

# %% [markdown]
# ## 3.2 Wordcloud - Amount of properties in Cities

# %%
from PIL import Image
from wordcloud import WordCloud

# %%
all_cities = ' '.join(df['locality'])
wordcloud = WordCloud(width=800, height=400, max_words=50).generate(all_cities)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Wordcloud Conclusion
# Uccle / Gent / Anrwerp / Bruxelles / Woluwe Saint
# All of these cities have a lot of properties for sale

# %% [markdown]
# ## 3.2 Correlation

# %%
num_cols = ['price', 'number_rooms', 'living_area', 'furnished'	, 'fireplace',	'terrace','terrace_area',	'garden'	,'garden_area'	,'surface_land'	,'number_facades'	,'swimming_pool']

# %%
df_nums = df[num_cols]
correlation_matrix = df_nums.corr()

plt.figure(figsize=(10, 8))
sns.color_palette("vlag", as_cmap=True)
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Correlation conclusion:
# the number of rooms and living area have a high correlation with the price. So the higher the price the (usually) more rooms / area of living.

# %% [markdown]
# ### Take Aways

# %% [markdown]
# Correlations:
# - price is highly overall correlated with living_area
# - number_rooms is highly overall correlated with living_area
# - living_area is highly overall correlated with price and number_rooms, surface_land
# - terrace_area is highly overall correlated with terrace
# - surface_land is highly overall correlated with living_area
# - terrace is highly overall correlated with terrace_area

# %%
sns.regplot(df, x='living_area', y='price', scatter_kws = {"color": "blue", "alpha": 0.1},
            line_kws = {"color": "red"})
plt.title('Price vs Living Area')
# Out:
# Text(0.5, 1.0, 'Price vs Living Area')

# %%
sns.regplot(df, x='number_rooms', y='living_area', scatter_kws = {"color": "blue", "alpha": 0.2},
            line_kws = {"color": "red"})
plt.title('Living Area vs Number of rooms')
# Out:
# Text(0.5, 1.0, 'Living Area vs Number of rooms')

# %%
sns.regplot(df, x='price', y='terrace_area', scatter_kws = {"color": "blue", "alpha": 0.2},
            line_kws = {"color": "red"})
plt.title('Terrace Area vs Price')
sns.set_style('darkgrid')

# %%
sns.regplot(df, x='surface_land', y='living_area', scatter_kws = {"color": "blue", "alpha": 0.2},
            line_kws = {"color": "red"})
plt.title('Surface land vs Living Area')
sns.set_style('darkgrid')

# %%
sns.regplot(df, x='number_rooms', y='price', scatter_kws = {"color": "blue", "alpha": 0.2},
            line_kws = {"color": "red"})
plt.title('Price vs Number of rooms')
plt.ylabel('Price in euros (million)')
plt.xlabel('Number of rooms')
sns.set_style('darkgrid')

# %%
sns.regplot(df, x='surface_land', y='price', scatter_kws = {"color": "blue", "alpha": 0.2},
            line_kws = {"color": "red"})
plt.title('Price vs Surface land')
plt.ylabel('Price in euros (million)')
plt.xlabel('Surface of land (m2)')
sns.set_style('darkgrid')

# %%
sns.regplot(df, x='garden_area', y='price', scatter_kws = {"color": "blue", "alpha": 0.2},
            line_kws = {"color": "red"})
plt.title('Price vs Garden area')
plt.ylabel('Price in euros (million))')
plt.xlabel('Surface of garden (m2)')
sns.set_style('darkgrid')

# %%
import seaborn as sns

sns.regplot(df, x='terrace', y='terrace_area')
plt.title('terrace vs terrace area')
plt.xlabel('Terrace')
plt.ylabel('Surface of terrace (m2)')
sns.set_style('darkgrid')

# %%
df.columns
# Out:
# Index(['locality', 'property_type', 'property_subtype', 'price',
#        'number_rooms', 'living_area', 'kitchen', 'furnished', 'fireplace',
#        'terrace', 'terrace_area', 'garden', 'garden_area', 'surface_land',
#        'number_facades', 'swimming_pool', 'building_state', 'region',
#        'province', 'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# ## Adding the Price per Square Meter column

# %%
df_new = df['price']/df['living_area']
df_new.to_frame()
df_coord = df[['latitude', 'longitude']]
df = pd.concat([df, df_new], axis=1)
df.rename(columns={0: 'price_per_area_m2'}, inplace=True)

# %%
# Draw the html map price per square meter
from utils.DrawHeatmap import drawheatmap_priceperm2

drawheatmap_priceperm2(df)

# %%
df.columns
# Out:
# Index(['locality', 'property_type', 'property_subtype', 'price',
#        'number_rooms', 'living_area', 'kitchen', 'furnished', 'fireplace',
#        'terrace', 'terrace_area', 'garden', 'garden_area', 'surface_land',
#        'number_facades', 'swimming_pool', 'building_state', 'region',
#        'province', 'latitude', 'longitude', 'price_per_area_m2'],
#       dtype='object')

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'property_type', y = 'price_per_area_m2',  data = df,ax=ax, hue='region')
plt.title('type of property vs Price per square meter')
plt.xlabel('Type of property')
plt.ylabel('Price per square meter (euro)')
ticks = plt.setp(ax.get_xticklabels(),rotation=45)
