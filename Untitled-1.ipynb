# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/cleaned.csv').drop(columns=['Unnamed: 0'])

# %%
sns.displot(df['price'], rug=True, kind='kde', fill=True)

# %%
sns.set_style('darkgrid')
sns.despine(left=True)
sns.lmplot(data=df, x='living_area', y='price', hue='property_type', palette='CMRmap').set(xlabel='Living Area (m2)', ylabel='Price (in million euros)')

# %%
sns.palplot(sns.color_palette("Purples", 10))

# %%
sns.set()
sns.lmplot(data=df, x='living_area', y='price', hue='property_subtype')

# %%
sns.set_style('darkgrid')
sns.lmplot(data=df, x='living_area', y='price', row='building_state', palette='Reds')

# %%
df.columns
# Out:
# Index(['locality', 'property_type', 'property_subtype', 'price',
#        'number_rooms', 'living_area', 'kitchen', 'furnished', 'fireplace',
#        'terrace', 'terrace_area', 'garden', 'garden_area', 'surface_land',
#        'number_facades', 'swimming_pool', 'building_state', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10081 entries, 0 to 10080
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   locality          10081 non-null  object
#  1   property_type     10081 non-null  object
#  2   property_subtype  10081 non-null  object
#  3   price             10081 non-null  float64
#  4   number_rooms      10081 non-null  float64
#  5   living_area       10081 non-null  float64
#  6   kitchen           10081 non-null  object
#  7   furnished         10081 non-null  int64
#  8   fireplace         10081 non-null  float64
#  9   terrace           10081 non-null  int64
#  10  terrace_area      10081 non-null  float64
#  11  garden            10081 non-null  int64
#  12  garden_area       10081 non-null  float64
#  13  surface_land      10081 non-null  float64
#  14  number_facades    10081 non-null  float64
#  15  swimming_pool     10081 non-null  int64
#  16  building_state    10081 non-null  object
#  17  latitude          10081 non-null  float64
#  18  longitude         10081 non-null  float64
# dtypes: float64(10), int64(4), object(5)
# memory usage: 1.5+ MB

# %%
df.head()
# Out:
#   locality property_type property_subtype     price  number_rooms  \
# 0      Ham         HOUSE            VILLA  429500.0           4.0
# 1      Ham         HOUSE            HOUSE  399500.0           3.0
# 2      Ham         HOUSE            HOUSE  381000.0           3.0
# 3      Ham         HOUSE            HOUSE  393500.0           3.0
# 4      Ham         HOUSE            HOUSE  315000.0           3.0
#
#    living_area         kitchen  furnished  fireplace  terrace  terrace_area  \
# 0        215.0       INSTALLED          0        0.0        0           0.0
# 1        197.0  HYPER_EQUIPPED          0        0.0        0           0.0
# 2        197.0  HYPER_EQUIPPED          0        0.0        0           0.0
# 3        192.0  HYPER_EQUIPPED          0        0.0        0           0.0
# 4        197.0   NOT_INSTALLED          0        0.0        0           0.0
#
#    garden  garden_area  surface_land  number_facades  swimming_pool  \
# 0       1          0.0        1472.0             4.0              0
# 1       0          0.0         461.0             3.0              0
# 2       0          0.0         343.0             3.0              0
# 3       0          0.0         392.0             3.0              0
# 4       0          0.0         509.0             3.0              0
#
#   building_state   latitude  longitude
# 0           GOOD  49.746322   3.073303
# 1         AS_NEW  49.746322   3.073303
# 2         AS_NEW  49.746322   3.073303
# 3         AS_NEW  49.746322   3.073303
# 4         AS_NEW  49.746322   3.073303
